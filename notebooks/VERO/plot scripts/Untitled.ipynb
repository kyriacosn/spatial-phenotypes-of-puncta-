# %%
from gstools import SRF, Gaussian

x = y = range(200)

# %%
model = Gaussian(dim=2, var=1, len_scale=10)
srf = SRF(model, seed=20170519)

# %%
field = srf.structured([x, y])
srf.plot(colours = "Blues")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 field = srf.structured([x, y])
# ----> 2 srf.plot(colours = "Blues")
#
# File ~\AppData\Roaming\Python\Python38\site-packages\gstools\field\base.py:467, in Field.plot(self, field, fig, ax, **kwargs)
#     461     raise ValueError(
#     462         "Field value type not set! "
#     463         "Specify 'scalar' or 'vector' before plotting."
#     464     )
#     466 if self.value_type == "scalar":
# --> 467     r = plot_field(self, field, fig, ax, **kwargs)
#     468 elif self.value_type == "vector":
#     469     if self.dim == 2:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\gstools\field\plot.py:57, in plot_field(fld, field, fig, ax, **kwargs)
#      55 if fld.dim == 1:
#      56     return plot_1d(fld.pos, fld[field], fig, ax, **kwargs)
# ---> 57 return plot_nd(
#      58     fld.pos, fld[field], fld.mesh_type, fig, ax, fld.latlon, **kwargs
#      59 )
#
# File ~\AppData\Roaming\Python\Python38\site-packages\gstools\field\plot.py:165, in plot_nd(pos, field, mesh_type, fig, ax, latlon, resolution, ax_names, aspect, show_colorbar, convex_hull, contour_plot, **kwargs)
#     163 assert not latlon or dim == 2
#     164 if dim == 2 and contour_plot:
# --> 165     return _plot_2d(
#     166         pos, field, mesh_type, fig, ax, latlon, ax_names, **kwargs
#     167     )
#     168 pos = pos[::-1] if latlon else pos
#     169 field = field.T if (latlon and mesh_type != "unstructured") else field
#
# TypeError: _plot_2d() got an unexpected keyword argument 'colours'

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.imshow((srf["field"]),cmap = "Blues")
