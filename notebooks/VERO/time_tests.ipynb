# %%
import matplotlib.pyplot as plt
import numpy as np
N_fit =  [1,2,3,4,5,6]

T_fit = np.array([0.9,1.93,4.51666666667,6.13333333333,18.6, 31.9333333333])
T_predall = np.array([0.1,0.63,1.66,2.13,4.74,6.5])
T_pred1 = np.array([0.1,0.65,1.5833,2.1,4.73,7.2])

Nfit2pred = [ ]

# %%
plt.scatter(N_fit,T_fit,label = "fit lgcp")
plt.scatter(N_fit,T_predall, label = "predict(fit,n.samples = 1)")
plt.xlabel("# of realizations fitted")
plt.ylabel("computation time [minutes]")
plt.legend()

plt.savefig("Tfit_Tpred_N.png")

# %%
#plt.scatter(N_fit,T_fit,label = "fit lgcp")
plt.plot(N_fit,T_predall/T_fit, label = "predict(fit,n.samples = 1)")
plt.xlabel("# of realizations fitted")
plt.ylabel(r"$T_{predict} \quad / \quad T_{fit}$",size = 10)
plt.savefig("T_pred_div_fit.png")
#plt.legend()

# %%
plt.scatter(N_fit,T_pred1,label = "predict on one realization ")
plt.scatter(N_fit,T_predall, label = "predict(fit,n.samples = 1)")
plt.xlabel("# of realizations fitted")
plt.ylabel("computation time [minutes]")
plt.legend()
plt.savefig("pred_one_all.png")

# %%
plt.scatter(N_fit,T_fit,label = "fit lgcp")
plt.scatter(N_fit,T_predall, label = "predict(fit,n.samples = 1)")
plt.xlabel("# of realizations fitted")
plt.ylabel("computation time [minutes]")
plt.legend()
